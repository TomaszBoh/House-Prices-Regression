# %% [markdown]
# # House Prices prediction from Kaggle

# %%
import pandas as pd

dataset = pd.read_csv(r"C:\Users\User\Desktop\Datascience\houses_price_regression\train.csv")

dataset.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
dataset.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
print(dataset['SalePrice'].describe())
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Checking Houses Prices distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

plt.figure(figsize=(9,8))
sns.distplot(dataset['SalePrice'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8012\3798238860.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['SalePrice'], color='g', bins=100, hist_kws={'alpha': 0.4});

# %%
list(set(dataset.dtypes.tolist()))
# Out:
# [dtype('float64'), dtype('O'), dtype('int64')]

# %%
df_num = dataset.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %% [markdown]
# ### Checking numeric variables distirubtions

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
import numpy as np

def split_dataset(dataset, test_ratio=0.3):
    test_indices = np.random.rand(len(dataset))<test_ratio
    return dataset[~test_indices], dataset[test_indices]

train_ds_pd, valid_ds_pd = split_dataset(dataset)
print("{} examples in training, {} exampes in testing".format(len(train_ds_pd), len(valid_ds_pd)))
# Out:
# 1024 examples in training, 436 exampes in testing

# %% [markdown]
# ### Creating a correlation matrix to find feature variables for prediction

# %%
plt.figure(figsize=(19,16))
plt.matshow(df_num.corr(), cmap='coolwarm', fignum=1)

#dodanie etykiest do osi
plt.xticks(range(len(df_num.columns)), df_num.columns, rotation=45)
plt.yticks(range(len(df_num.columns)), df_num.columns)

#pasek koloru
plt.colorbar()


plt.show()

# %%
#OverallCond, FullBath, GarageArea, YearBuilt, TotRmsAbvGrd, 3SsnPorch
y=dataset.SalePrice
dataset_features = ['OverallCond', 'FullBath', 'GarageArea', 'YearBuilt', 'TotRmsAbvGrd', '3SsnPorch']
X= dataset[dataset_features]
X.describe()
# Out:
#        OverallCond     FullBath   GarageArea    YearBuilt  TotRmsAbvGrd  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean      5.575342     1.565068   472.980137  1971.267808      6.517808
# std       1.112799     0.550916   213.804841    30.202904      1.625393
# min       1.000000     0.000000     0.000000  1872.000000      2.000000
# 25%       5.000000     1.000000   334.500000  1954.000000      5.000000
# 50%       5.000000     2.000000   480.000000  1973.000000      6.000000
# 75%       6.000000     2.000000   576.000000  2000.000000      7.000000
# max       9.000000     3.000000  1418.000000  2010.000000     14.000000
#
#          3SsnPorch
# count  1460.000000
# mean      3.409589
# std      29.317331
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max     508.000000

# %%
X.head()
# Out:
#    OverallCond  FullBath  GarageArea  YearBuilt  TotRmsAbvGrd  3SsnPorch
# 0            5         2         548       2003             8          0
# 1            8         2         460       1976             6          0
# 2            5         2         608       2001             6          0
# 3            5         1         642       1915             7          0
# 4            5         2         836       2000             9          0

# %% [markdown]
# ##

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(random_state=1)
model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print("Predictions for following 5 houses:")
print(X.head())
print("Predictions are")
print(model.predict(X.head()))
# Out:
# Predictions for following 5 houses:
#    OverallCond  FullBath  GarageArea  YearBuilt  TotRmsAbvGrd  3SsnPorch
# 0            5         2         548       2003             8          0
# 1            8         2         460       1976             6          0
# 2            5         2         608       2001             6          0
# 3            5         1         642       1915             7          0
# 4            5         2         836       2000             9          0
# Predictions are
# [208500. 181500. 223500. 140000. 250000.]

# %%
from sklearn.metrics import mean_absolute_error

predicted_home_prices = model.predict(X)
mean_absolute_error(y, predicted_home_prices)
# Out:
# 585.2509132420091

# %%
from sklearn.model_selection import train_test_split
#splitting data into training and validation datasets

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=0)

#creating model
model = DecisionTreeRegressor()
model.fit(train_X, train_y)

#get predictions and validate data
val_predictions=model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 37970.87397260274

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

#changing number of leaf nodes
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
for max_leaf_nodes in [5, 50, 500, 5000, ]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d \t\t Mean Absolute Error: %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5 		 Mean Absolute Error: 37441
# Max leaf nodes: 50 		 Mean Absolute Error: 34527
# Max leaf nodes: 500 		 Mean Absolute Error: 37409
# Max leaf nodes: 5000 		 Mean Absolute Error: 38206

# %%
#using random forest
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)

house_preds=forest_model.predict(val_X)
print(mean_absolute_error(val_y, house_preds))
# Out:
# 29541.185425570777
